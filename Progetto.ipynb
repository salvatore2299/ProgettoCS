# %%
import pandas as pd
import re
import numpy as np
import datetime as dt
from ftfy import fix_encoding
import collections

# %%
dogs = pd.read_csv('dogs.csv' )
travels = pd.read_csv('dogTravel.csv')
colnames=['state' , 'population'] 
states = pd.read_csv('NST-EST2021-POP.csv', names=colnames, header=None)

# %%
dogs.columns.values
# Out:
# array(['id', 'org_id', 'url', 'type.x', 'species', 'breed_primary',
#        'breed_secondary', 'breed_mixed', 'breed_unknown', 'color_primary',
#        'color_secondary', 'color_tertiary', 'age', 'sex', 'size', 'coat',
#        'fixed', 'house_trained', 'declawed', 'special_needs',
#        'shots_current', 'env_children', 'env_dogs', 'env_cats', 'name',
#        'status', 'posted', 'contact_city', 'contact_state', 'contact_zip',
#        'contact_country', 'stateQ', 'accessed', 'type.y', 'description',
#        'stay_duration', 'stay_cost'], dtype=object)

# %% [markdown]
# # 1. Extract all dogs with status that is not adoptable

# %%
dogs['status']
# Out:
# 0        adoptable
# 1        adoptable
# 2        adoptable
# 3        adoptable
# 4        adoptable
#            ...
# 58175    adoptable
# 58176    adoptable
# 58177    adoptable
# 58178    adoptable
# 58179    adoptable
# Name: status, Length: 58180, dtype: object

# %%
dogs[dogs['status'] != 'adoptable'][['id','org_id','status', 'posted', 'contact_city', 'contact_state', 'contact_zip',
       'contact_country', 'stateQ', 'accessed']]
# Out:
#              id  org_id                    status          posted  \
# 644    41330726   NV173  2018-04-05T05:18:31+0000       Las Vegas
# 5549   38169117   AZ414  2017-05-26T21:43:16+0000        Chandler
# 10888  45833989    NY98  2019-09-01T15:12:06+0000          Albany
# 11983  45515547    NY98  2019-08-06T12:15:58+0000          Albany
# 12495  45294115    NY98  2019-07-18T14:20:58+0000          Albany
# 12600  45229004  NY1436  2019-07-11T20:34:42+0000      Saugerties
# 12613  45227052  NY1436  2019-07-11T14:16:38+0000      Saugerties
# 17619  45569380  CA1209  2019-08-10T16:00:35+0000         Bristow
# 18611  44694387   MD295  2019-05-14T21:09:27+0000   Silver Spring
# 19747  36978896   VA127  2016-12-15T13:33:43+0000      Gettysburg
# 19845  33218331   VA127  2015-09-07T12:57:27+0000      Gettysburg
# 22161  42092005   PA738  2018-07-05T00:55:08+0000           Media
# 22229  39594038   PA562  2017-10-07T23:48:20+0000    Feasterville
# 29283  45895274   IL688  2019-09-07T04:09:12+0000           Paris
# 30471  45964719   IN694  2019-09-13T19:39:28+0000     Mooresville
# 31581  44538917   OH907  2019-04-25T01:56:52+0000            Ross
# 31888  41430442   OH907  2018-04-18T13:45:46+0000            Ross
# 33000  45907639   IN714  2019-09-08T18:21:21+0000  Jeffersonville
# 33527  45362806   OH852  2019-07-25T19:53:21+0000      Cincinnati
# 34188  32590894   IN595  2015-06-29T23:58:09+0000           Paoli
# 35065  31426754   LA256  2015-02-07T13:06:43+0000    lake charles
# 44830  46037827   NM133  2019-09-20T01:50:51+0000     Albuquerque
# 53168  44044071   TN669  2019-02-18T12:02:48+0000      Cookeville
# 53539  27521132   TN577  2013-10-10T13:57:39+0000       Nashville
# 55434  38473806   VA486  2017-06-16T18:44:33+0000        Rustburg
# 55467  34101432   VA628  2015-12-25T12:28:30+0000      Midlothian
# 55915  45958435   WA581  2019-09-13T06:08:17+0000         Seattle
# 55975  45927580   WA581  2019-09-10T16:43:35+0000         Seattle
# 56013  45916348   WA581  2019-09-09T17:05:17+0000         Seattle
# 56248  45733027   WA581  2019-08-24T16:32:31+0000         Seattle
# 56464  45413997   WA581  2019-07-31T16:21:07+0000         Seattle
# 56473  45406516   WA581  2019-07-29T21:50:16+0000         Seattle
# 56541  45264615   WA581  2019-07-15T16:57:05+0000         Seattle
#
#       contact_city contact_state contact_zip contact_country      stateQ  \
# 644             NV         89146          US           89009  2019-09-20
# 5549            AZ         85249          US              AZ  2019-09-20
# 10888           NY         12220          US              CT  2019-09-20
# 11983           NY         12220          US              CT  2019-09-20
# 12495           NY         12220          US              CT  2019-09-20
# 12600           NY         12477          US              CT  2019-09-20
# 12613           NY         12477          US              CT  2019-09-20
# 17619           VA         20136          US              DC  2019-09-20
# 18611           MD         20905          US              DC  2019-09-20
# 19747           PA         17325          US              DC  2019-09-20
# 19845           PA         17325          US              DC  2019-09-20
# 22161           PA         19063          US              DE  2019-09-20
# 22229           PA         19053          US              DE  2019-09-20
# 29283           IL         61944          US              IL  2019-09-20
# 30471           IN         46158          US              IN  2019-09-20
# 31581           OH         45061          US              IN  2019-09-20
# 31888           OH         45061          US              IN  2019-09-20
# 33000           IN         47131          US              KY  2019-09-20
# 33527           OH         45249          US              KY  2019-09-20
# 34188           IN         47454          US              KY  2019-09-20
# 35065           LA         70601          US              LA  2019-09-20
# 44830           NM         87108          US              NM  2019-09-20
# 53168           TN         38506          US              TN  2019-09-20
# 53539           TN         37189          US              TN  2019-09-20
# 55434           VA         24588          US              VA  2019-09-20
# 55467           VA         23112          US              VA  2019-09-20
# 55915           WA         98106          US              WA  2019-09-20
# 55975           WA         98106          US              WA  2019-09-20
# 56013           WA         98106          US              WA  2019-09-20
# 56248           WA         98106          US              WA  2019-09-20
# 56464           WA         98106          US              WA  2019-09-20
# 56473           WA         98106          US              WA  2019-09-20
# 56541           WA         98106          US              WA  2019-09-20
#
#       accessed
# 644        NaN
# 5549       NaN
# 10888      NaN
# 11983      NaN
# 12495      NaN
# 12600      NaN
# 12613      NaN
# 17619      NaN
# 18611      NaN
# 19747      NaN
# 19845      NaN
# 22161      NaN
# 22229      NaN
# 29283      NaN
# 30471      NaN
# 31581      NaN
# 31888      NaN
# 33000      NaN
# 33527      NaN
# 34188      NaN
# 35065      NaN
# 44830      NaN
# 53168      NaN
# 53539      NaN
# 55434      NaN
# 55467      NaN
# 55915      NaN
# 55975      NaN
# 56013      NaN
# 56248      NaN
# 56464      NaN
# 56473      NaN
# 56541      NaN

# %%
col = ['status', 'posted', 'contact_city', 'contact_state', 'contact_zip',
       'contact_country', 'stateQ', 'accessed']
m = dogs['status'] != 'adoptable'

dogs.loc[m,col] = dogs.loc[m , col].shift(axis=1)

# %%
dogs[dogs['status'] != 'adoptable'][['id','org_id','status', 'posted', 'contact_city', 'contact_state', 'contact_zip',
       'contact_country', 'stateQ', 'accessed']]
# Out:
#              id  org_id status                    posted    contact_city  \
# 644    41330726   NV173    NaN  2018-04-05T05:18:31+0000       Las Vegas
# 5549   38169117   AZ414    NaN  2017-05-26T21:43:16+0000        Chandler
# 10888  45833989    NY98    NaN  2019-09-01T15:12:06+0000          Albany
# 11983  45515547    NY98    NaN  2019-08-06T12:15:58+0000          Albany
# 12495  45294115    NY98    NaN  2019-07-18T14:20:58+0000          Albany
# 12600  45229004  NY1436    NaN  2019-07-11T20:34:42+0000      Saugerties
# 12613  45227052  NY1436    NaN  2019-07-11T14:16:38+0000      Saugerties
# 17619  45569380  CA1209    NaN  2019-08-10T16:00:35+0000         Bristow
# 18611  44694387   MD295    NaN  2019-05-14T21:09:27+0000   Silver Spring
# 19747  36978896   VA127    NaN  2016-12-15T13:33:43+0000      Gettysburg
# 19845  33218331   VA127    NaN  2015-09-07T12:57:27+0000      Gettysburg
# 22161  42092005   PA738    NaN  2018-07-05T00:55:08+0000           Media
# 22229  39594038   PA562    NaN  2017-10-07T23:48:20+0000    Feasterville
# 29283  45895274   IL688    NaN  2019-09-07T04:09:12+0000           Paris
# 30471  45964719   IN694    NaN  2019-09-13T19:39:28+0000     Mooresville
# 31581  44538917   OH907    NaN  2019-04-25T01:56:52+0000            Ross
# 31888  41430442   OH907    NaN  2018-04-18T13:45:46+0000            Ross
# 33000  45907639   IN714    NaN  2019-09-08T18:21:21+0000  Jeffersonville
# 33527  45362806   OH852    NaN  2019-07-25T19:53:21+0000      Cincinnati
# 34188  32590894   IN595    NaN  2015-06-29T23:58:09+0000           Paoli
# 35065  31426754   LA256    NaN  2015-02-07T13:06:43+0000    lake charles
# 44830  46037827   NM133    NaN  2019-09-20T01:50:51+0000     Albuquerque
# 53168  44044071   TN669    NaN  2019-02-18T12:02:48+0000      Cookeville
# 53539  27521132   TN577    NaN  2013-10-10T13:57:39+0000       Nashville
# 55434  38473806   VA486    NaN  2017-06-16T18:44:33+0000        Rustburg
# 55467  34101432   VA628    NaN  2015-12-25T12:28:30+0000      Midlothian
# 55915  45958435   WA581    NaN  2019-09-13T06:08:17+0000         Seattle
# 55975  45927580   WA581    NaN  2019-09-10T16:43:35+0000         Seattle
# 56013  45916348   WA581    NaN  2019-09-09T17:05:17+0000         Seattle
# 56248  45733027   WA581    NaN  2019-08-24T16:32:31+0000         Seattle
# 56464  45413997   WA581    NaN  2019-07-31T16:21:07+0000         Seattle
# 56473  45406516   WA581    NaN  2019-07-29T21:50:16+0000         Seattle
# 56541  45264615   WA581    NaN  2019-07-15T16:57:05+0000         Seattle
#
#       contact_state contact_zip contact_country stateQ    accessed
# 644              NV       89146              US  89009  2019-09-20
# 5549             AZ       85249              US     AZ  2019-09-20
# 10888            NY       12220              US     CT  2019-09-20
# 11983            NY       12220              US     CT  2019-09-20
# 12495            NY       12220              US     CT  2019-09-20
# 12600            NY       12477              US     CT  2019-09-20
# 12613            NY       12477              US     CT  2019-09-20
# 17619            VA       20136              US     DC  2019-09-20
# 18611            MD       20905              US     DC  2019-09-20
# 19747            PA       17325              US     DC  2019-09-20
# 19845            PA       17325              US     DC  2019-09-20
# 22161            PA       19063              US     DE  2019-09-20
# 22229            PA       19053              US     DE  2019-09-20
# 29283            IL       61944              US     IL  2019-09-20
# 30471            IN       46158              US     IN  2019-09-20
# 31581            OH       45061              US     IN  2019-09-20
# 31888            OH       45061              US     IN  2019-09-20
# 33000            IN       47131              US     KY  2019-09-20
# 33527            OH       45249              US     KY  2019-09-20
# 34188            IN       47454              US     KY  2019-09-20
# 35065            LA       70601              US     LA  2019-09-20
# 44830            NM       87108              US     NM  2019-09-20
# 53168            TN       38506              US     TN  2019-09-20
# 53539            TN       37189              US     TN  2019-09-20
# 55434            VA       24588              US     VA  2019-09-20
# 55467            VA       23112              US     VA  2019-09-20
# 55915            WA       98106              US     WA  2019-09-20
# 55975            WA       98106              US     WA  2019-09-20
# 56013            WA       98106              US     WA  2019-09-20
# 56248            WA       98106              US     WA  2019-09-20
# 56464            WA       98106              US     WA  2019-09-20
# 56473            WA       98106              US     WA  2019-09-20
# 56541            WA       98106              US     WA  2019-09-20

# %% [markdown]
# # 2. For each (primary) breed, determine the number of dogs

# %%
dogs.groupby('breed_primary').size()
# Out:
# breed_primary
# Affenpinscher                         17
# Afghan Hound                           4
# Airedale Terrier                      19
# Akbash                                 3
# Akita                                181
#                                     ...
# Wirehaired Pointing Griffon            1
# Wirehaired Terrier                    60
# Xoloitzcuintli / Mexican Hairless     11
# Yellow Labrador Retriever            158
# Yorkshire Terrier                    360
# Length: 216, dtype: int64

# %% [markdown]
# # 3. For each (primary) breed, determine the ratio between the number of dogs of Mixed Breed and those not of Mixed Breed. Hint: look at the secondary_breed.

# %%
dogs[['breed_primary','breed_secondary']]
# Out:
#                         breed_primary                      breed_secondary
# 0      American Staffordshire Terrier                          Mixed Breed
# 1                    Pit Bull Terrier                          Mixed Breed
# 2                            Shepherd                                  NaN
# 3                 German Shepherd Dog                                  NaN
# 4                           Dachshund                                  NaN
# ...                               ...                                  ...
# 58175                   Border Collie                                  NaN
# 58176             Australian Shepherd  Australian Cattle Dog / Blue Heeler
# 58177                   Border Collie                                  NaN
# 58178                           Boxer                          Mixed Breed
# 58179              Labrador Retriever                     Pit Bull Terrier
#
# [58180 rows x 2 columns]

# %%
(dogs[dogs['breed_secondary'].notnull()].groupby('breed_primary').size() / dogs[dogs['breed_secondary'].isnull()].groupby('breed_primary').size())
# Out:
# breed_primary
# Affenpinscher                        0.133333
# Afghan Hound                         0.333333
# Airedale Terrier                     0.900000
# Akbash                                    NaN
# Akita                                0.403101
#                                        ...
# Wirehaired Pointing Griffon               NaN
# Wirehaired Terrier                   0.428571
# Xoloitzcuintli / Mexican Hairless    0.571429
# Yellow Labrador Retriever            0.645833
# Yorkshire Terrier                    0.558442
# Length: 216, dtype: float64

# %% [markdown]
# # 4. For each (primary) breed, determine the earliest and the latest posted timestamp.

# %%
dogs['posted'] = pd.to_datetime(dogs['posted'] , format="%Y-%m-%dT%H:%M:%S%z")
dogs['posted']
# Out:
# 0       2019-09-20 16:37:59+00:00
# 1       2019-09-20 16:24:57+00:00
# 2       2019-09-20 14:10:11+00:00
# 3       2019-09-20 10:08:22+00:00
# 4       2019-09-20 06:48:30+00:00
#                    ...
# 58175   2019-05-03 14:23:49+00:00
# 58176   2019-04-13 16:20:24+00:00
# 58177   2018-09-27 04:18:56+00:00
# 58178   2018-09-12 05:03:38+00:00
# 58179   2018-09-03 20:42:24+00:00
# Name: posted, Length: 58180, dtype: datetime64[ns, UTC]

# %%
dogs.groupby('breed_primary')['posted'].min()
# Out:
# breed_primary
# Affenpinscher                       2012-03-08 10:27:33+00:00
# Afghan Hound                        2017-06-29 23:28:51+00:00
# Airedale Terrier                    2014-06-13 12:59:36+00:00
# Akbash                              2019-07-21 00:35:59+00:00
# Akita                               2012-03-03 09:31:08+00:00
#                                                ...
# Wirehaired Pointing Griffon         2016-06-29 20:03:55+00:00
# Wirehaired Terrier                  2012-11-27 14:07:54+00:00
# Xoloitzcuintli / Mexican Hairless   2007-02-01 00:00:00+00:00
# Yellow Labrador Retriever           2010-05-31 00:00:00+00:00
# Yorkshire Terrier                   2012-02-04 17:14:52+00:00
# Name: posted, Length: 216, dtype: datetime64[ns, UTC]

# %%
dogs.groupby('breed_primary')['posted'].max()
# Out:
# breed_primary
# Affenpinscher                       2019-09-14 10:10:51+00:00
# Afghan Hound                        2019-07-27 00:38:48+00:00
# Airedale Terrier                    2019-09-19 18:40:39+00:00
# Akbash                              2019-08-23 17:11:04+00:00
# Akita                               2019-09-20 15:19:57+00:00
#                                                ...
# Wirehaired Pointing Griffon         2016-06-29 20:03:55+00:00
# Wirehaired Terrier                  2019-09-19 22:52:45+00:00
# Xoloitzcuintli / Mexican Hairless   2019-09-08 11:15:54+00:00
# Yellow Labrador Retriever           2019-09-20 06:30:27+00:00
# Yorkshire Terrier                   2019-09-20 16:56:38+00:00
# Name: posted, Length: 216, dtype: datetime64[ns, UTC]

# %% [markdown]
# # 5. For each state, compute the sex imbalance, that is the difference between male and female dogs. In which state this imbalance is largest?

# %%
dogs['contact_state'].unique()
# Out:
# array(['NV', 'AZ', 'UT', 'CA', 'AK', 'AL', 'AR', 'CO', 'NY', 'MA', 'CT',
#        'RI', 'NJ', 'NH', 'VT', 'MD', 'VA', 'DC', 'PA', 'WV', 'DE', 'FL',
#        'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'OH', 'KS', 'KY', 'LA', 'ME',
#        'QC', 'NB', 'MI', 'MN', 'WI', 'MO', 'MS', 'MT', 'NC', 'SC', 'ND',
#        'NE', 'NM', 'OK', 'OR', 'SD', 'TN', 'TX', 'WA', 'WY'], dtype=object)

# %%
dogs[dogs['sex']=='Unknown']['sex']
# Out:
# 5780     Unknown
# 34991    Unknown
# 34992    Unknown
# Name: sex, dtype: object

# %%
res = dogs.pivot_table(index='contact_state', columns='sex', aggfunc='size', fill_value=0)
res.drop('Unknown', axis=1, inplace=True)
res['imbalance'] = abs(res['Male'] - res['Female'])
res
# Out:
# sex            Female  Male  imbalance
# contact_state
# AK                  7     8          1
# AL                716   712          4
# AR                351   344          7
# AZ               1067  1181        114
# CA                777   887        110
# CO                912   861         51
# CT                682   740         58
# DC                176   160         16
# DE                148   148          0
# FL               1279  1380        101
# GA               1727  1752         25
# HI                 28    41         13
# IA                202   283         81
# ID                 24    25          1
# IL                507   608        101
# IN                851  1029        178
# KS                235   235          0
# KY                507   616        109
# LA                444   467         23
# MA                459   487         28
# MD                679   815        136
# ME                287   258         29
# MI                317   356         39
# MN                462   496         34
# MO                425   495         70
# MS                275   235         40
# MT                  7    11          4
# NB                  1     1          0
# NC               1282  1345         63
# ND                 28    36          8
# NE                 61    59          2
# NH                172   163          9
# NJ               1483  1539         56
# NM                310   327         17
# NV                402   456         54
# NY               1945  2062        117
# OH               1234  1439        205
# OK                814   822          8
# OR                 33    58         25
# PA               1371  1454         83
# QC                  7     7          0
# RI                306   301          5
# SC                759   859        100
# SD                  7    17         10
# TN                826   945        119
# TX                287   279          8
# UT                203   282         79
# VA               1451  1610        159
# VT                234   276         42
# WA                598   686         88
# WI                265   277         12
# WV                232   333        101
# WY                 21    31         10

# %%
massimo= res['imbalance'].max()
res[res['imbalance'] == massimo]
# Out:
# sex            Female  Male  imbalance
# contact_state
# OH               1234  1439        205

# %% [markdown]
# # 6. For each pair (age, size), determine the average duration of the stay and the average cost of stay.

# %%
dogs.groupby(['age' , 'size'])[['stay_duration' , 'stay_cost']].mean()
# Out:
#                     stay_duration   stay_cost
# age    size
# Adult  Extra Large      89.015414  232.591561
#        Large            89.531943  238.661141
#        Medium           89.421036  238.258977
#        Small            89.407479  238.974838
# Baby   Extra Large      87.032967  237.180879
#        Large            89.701564  238.698827
#        Medium           89.577668  237.108131
#        Small            89.958291  239.083810
# Senior Extra Large      88.861111  235.232361
#        Large            88.984298  237.507364
#        Medium           89.810052  238.514615
#        Small            89.073626  238.282286
# Young  Extra Large      90.586345  245.835582
#        Large            90.104206  238.149506
#        Medium           89.515123  239.304603
#        Small            89.814275  241.540069

# %% [markdown]
# # 7. Find the dogs involved in at least 3 travels. Also list the breed of those dogs.

# %%
num_viaggi = travels.groupby(['id'], as_index=False).size()
viaggi3 = num_viaggi[num_viaggi['size'] >= 3]
pd.merge(dogs[['id', 'breed_primary' ]] , viaggi3 , on = 'id')
# Out:
#            id        breed_primary  size
# 0    45642530                Jindo     4
# 1    46039420        Border Collie     4
# 2    40036107     Pit Bull Terrier     3
# 3    45851842   Labrador Retriever     3
# 4    45841145          Mixed Breed     3
# ..        ...                  ...   ...
# 558  41144335            Chihuahua     3
# 559  40103682          Rat Terrier     3
# 560  38664932     Pit Bull Terrier     3
# 561  38495992     Pit Bull Terrier     3
# 562  45588395  German Shepherd Dog     3
#
# [563 rows x 3 columns]

# %% [markdown]
# # 8. Fix the travels table so that the correct state is computed from the manual and the found fields. If manual is not missing, then it overrides what is stored in found.

# %%
travels['found'].mask(travels['manual'].notnull() , travels['manual'] , inplace=True)
travels[['found' , 'manual']]
# Out:
#             found    manual
# 0        Arkansas       NaN
# 1         Bahamas   Bahamas
# 2        Maryland  Maryland
# 3         Adaptil       NaN
# 4     Afghanistan       NaN
# ...           ...       ...
# 6189           WV       NaN
# 6190      Wyoming       NaN
# 6191       Yazmin       NaN
# 6192         Ohio      Ohio
# 6193         Zazu       NaN
#
# [6194 rows x 2 columns]

# %% [markdown]
# # 9. For each state, compute the ratio between the number of travels and the population.

# %%
travels['contact_state'].unique()
# Out:
# array(['MN', 'FL', 'MD', 'CO', 'CT', 'OH', 'AL', 'NY', 'NJ', 'PA', 'VA',
#        'GA', 'ME', 'NH', 'MI', 'VT', 'TN', 'WI', 'NM', 'OR', 'WA', 'IA',
#        'KY', 'NV', 'UT', 'AZ', 'NC', 'AR', 'MA', 'RI', 'OK', 'CA', 'IN',
#        'SC', 'IL', 'MO', 'TX', 'DC', 'KS', 'DE', 'WV', 'NB', 'MS', 'LA',
#        '17325'], dtype=object)

# %%
travels[travels['contact_state'] == '17325']
# Out:
#       index        id contact_city contact_state  \
# 3237   3237  36978896           PA         17325
# 3238   3238  33218331           PA         17325
# 3714   3714  36978896           PA         17325
# 3715   3715  33218331           PA         17325
# 6029   6029  36978896           PA         17325
# 6030   6030  33218331           PA         17325
# 6074   6074  36978896           PA         17325
# 6075   6075  33218331           PA         17325
# 6133   6133  36978896           PA         17325
# 6134   6134  33218331           PA         17325
#
#                                             description          found manual  \
# 3237  Maddie is our little Miss Cutie Patootie! She ...       New York    NaN
# 3238  Born in August 2014, Bucky has a great sense o...       New York    NaN
# 3714  Maddie is our little Miss Cutie Patootie! She ...   Pennsylvania    NaN
# 3715  Born in August 2014, Bucky has a great sense o...   Pennsylvania    NaN
# 6029  Maddie is our little Miss Cutie Patootie! She ...       Virginia    NaN
# 6030  Born in August 2014, Bucky has a great sense o...       Virginia    NaN
# 6074  Maddie is our little Miss Cutie Patootie! She ...  Washington DC    NaN
# 6075  Born in August 2014, Bucky has a great sense o...  Washington DC    NaN
# 6133  Maddie is our little Miss Cutie Patootie! She ...  West Virginia    NaN
# 6134  Born in August 2014, Bucky has a great sense o...  West Virginia    NaN
#
#      remove still_there
# 3237   True         NaN
# 3238   True         NaN
# 3714   True         NaN
# 3715   True         NaN
# 6029   True         NaN
# 6030   True         NaN
# 6074   True         NaN
# 6075   True         NaN
# 6133   True         NaN
# 6134   True         NaN

# %%
travels['contact_state'].mask(travels['contact_state']=='17325' , travels['contact_city'] , inplace=True)
travels[travels['contact_city']=='PA']
# Out:
#       index        id contact_city contact_state  \
# 2472   2472  36978896           PA            PA
# 2473   2473  33218331           PA            PA
# 3190   3190  36978896           PA            PA
# 3191   3191  33218331           PA            PA
# 3237   3237  36978896           PA            PA
# 3238   3238  33218331           PA            PA
# 3714   3714  36978896           PA            PA
# 3715   3715  33218331           PA            PA
# 6029   6029  36978896           PA            PA
# 6030   6030  33218331           PA            PA
# 6074   6074  36978896           PA            PA
# 6075   6075  33218331           PA            PA
# 6133   6133  36978896           PA            PA
# 6134   6134  33218331           PA            PA
#
#                                             description          found manual  \
# 2472  Maddie is our little Miss Cutie Patootie! She ...       Maryland    NaN
# 2473  Born in August 2014, Bucky has a great sense o...       Maryland    NaN
# 3190  Maddie is our little Miss Cutie Patootie! She ...     New Jersey    NaN
# 3191  Born in August 2014, Bucky has a great sense o...     New Jersey    NaN
# 3237  Maddie is our little Miss Cutie Patootie! She ...       New York    NaN
# 3238  Born in August 2014, Bucky has a great sense o...       New York    NaN
# 3714  Maddie is our little Miss Cutie Patootie! She ...   Pennsylvania    NaN
# 3715  Born in August 2014, Bucky has a great sense o...   Pennsylvania    NaN
# 6029  Maddie is our little Miss Cutie Patootie! She ...       Virginia    NaN
# 6030  Born in August 2014, Bucky has a great sense o...       Virginia    NaN
# 6074  Maddie is our little Miss Cutie Patootie! She ...  Washington DC    NaN
# 6075  Born in August 2014, Bucky has a great sense o...  Washington DC    NaN
# 6133  Maddie is our little Miss Cutie Patootie! She ...  West Virginia    NaN
# 6134  Born in August 2014, Bucky has a great sense o...  West Virginia    NaN
#
#      remove still_there
# 2472   True         NaN
# 2473   True         NaN
# 3190   True         NaN
# 3191   True         NaN
# 3237   True         NaN
# 3238   True         NaN
# 3714   True         NaN
# 3715   True         NaN
# 6029   True         NaN
# 6030   True         NaN
# 6074   True         NaN
# 6075   True         NaN
# 6133   True         NaN
# 6134   True         NaN

# %%
lista = pd.read_csv('stati.csv')
lista
# Out:
#                    state  abbrev code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# 24           Mississippi   Miss.   MS
# 25              Missouri     Mo.   MO
# 26               Montana   Mont.   MT
# 27              Nebraska   Nebr.   NE
# 28                Nevada    Nev.   NV
# 29         New Hampshire    N.H.   NH
# 30            New Jersey    N.J.   NJ
# 31            New Mexico    N.M.   NM
# 32              New York    N.Y.   NY
# 33        North Carolina    N.C.   NC
# 34          North Dakota    N.D.   ND
# 35                  Ohio    Ohio   OH
# 36              Oklahoma   Okla.   OK
# 37                Oregon    Ore.   OR
# 38          Pennsylvania     Pa.   PA
# 39          Rhode Island    R.I.   RI
# 40        South Carolina    S.C.   SC
# 41          South Dakota    S.D.   SD
# 42             Tennessee   Tenn.   TN
# 43                 Texas    Tex.   TX
# 44                  Utah    Utah   UT
# 45               Vermont     Vt.   VT
# 46              Virginia     Va.   VA
# 47            Washington   Wash.   WA
# 48         West Virginia   W.Va.   WV
# 49             Wisconsin    Wis.   WI
# 50               Wyoming    Wyo.   WY

# %%
statipop = pd.merge(states, lista, on='state')
statipop
# Out:
#                    state  population  abbrev code
# 0                Alabama   5.024.279    Ala.   AL
# 1                 Alaska     733.391  Alaska   AK
# 2                Arizona   7.151.502   Ariz.   AZ
# 3               Arkansas   3.011.524    Ark.   AR
# 4             California  39.538.223  Calif.   CA
# 5               Colorado   5.773.714   Colo.   CO
# 6            Connecticut   3.605.944   Conn.   CT
# 7               Delaware     989.948    Del.   DE
# 8   District of Columbia     689.545    D.C.   DC
# 9                Florida  21.538.187    Fla.   FL
# 10               Georgia  10.711.908     Ga.   GA
# 11                Hawaii   1.455.271  Hawaii   HI
# 12                 Idaho   1.839.106   Idaho   ID
# 13              Illinois  12.812.508    Ill.   IL
# 14               Indiana   6.785.528    Ind.   IN
# 15                  Iowa   3.190.369    Iowa   IA
# 16                Kansas   2.937.880   Kans.   KS
# 17              Kentucky   4.505.836     Ky.   KY
# 18             Louisiana   4.657.757     La.   LA
# 19                 Maine   1.362.359   Maine   ME
# 20              Maryland   6.177.224     Md.   MD
# 21         Massachusetts   7.029.917   Mass.   MA
# 22              Michigan  10.077.331   Mich.   MI
# 23             Minnesota   5.706.494   Minn.   MN
# 24           Mississippi   2.961.279   Miss.   MS
# 25              Missouri   6.154.913     Mo.   MO
# 26               Montana   1.084.225   Mont.   MT
# 27              Nebraska   1.961.504   Nebr.   NE
# 28                Nevada   3.104.614    Nev.   NV
# 29         New Hampshire   1.377.529    N.H.   NH
# 30            New Jersey   9.288.994    N.J.   NJ
# 31            New Mexico   2.117.522    N.M.   NM
# 32              New York  20.201.249    N.Y.   NY
# 33        North Carolina  10.439.388    N.C.   NC
# 34          North Dakota     779.094    N.D.   ND
# 35                  Ohio  11.799.448    Ohio   OH
# 36              Oklahoma   3.959.353   Okla.   OK
# 37                Oregon   4.237.256    Ore.   OR
# 38          Pennsylvania  13.002.700     Pa.   PA
# 39          Rhode Island   1.097.379    R.I.   RI
# 40        South Carolina   5.118.425    S.C.   SC
# 41          South Dakota     886.667    S.D.   SD
# 42             Tennessee   6.910.840   Tenn.   TN
# 43                 Texas  29.145.505    Tex.   TX
# 44                  Utah   3.271.616    Utah   UT
# 45               Vermont     643.077     Vt.   VT
# 46              Virginia   8.631.393     Va.   VA
# 47            Washington   7.705.281   Wash.   WA
# 48         West Virginia   1.793.716   W.Va.   WV
# 49             Wisconsin   5.893.718    Wis.   WI
# 50               Wyoming     576.851    Wyo.   WY

# %%
prova = travels.groupby('contact_state',as_index=False).size()
tra_sta = pd.merge(statipop, prova, left_on='code' , right_on='contact_state')
tra_sta['ratio'] = tra_sta['size'] / tra_sta['population'].str.replace('\.' , '',regex= True).astype(int)
tra_sta[['state', 'population' , 'size' , 'ratio']]
# Out:
#                    state  population  size         ratio
# 0                Alabama   5.024.279    75  1.492751e-05
# 1                Arizona   7.151.502    70  9.788154e-06
# 2               Arkansas   3.011.524    10  3.320578e-06
# 3             California  39.538.223    28  7.081755e-07
# 4               Colorado   5.773.714   103  1.783947e-05
# 5            Connecticut   3.605.944    90  2.495879e-05
# 6               Delaware     989.948    57  5.757878e-05
# 7   District of Columbia     689.545   112  1.624259e-04
# 8                Florida  21.538.187   133  6.175079e-06
# 9                Georgia  10.711.908   109  1.017559e-05
# 10              Illinois  12.812.508    37  2.887803e-06
# 11               Indiana   6.785.528    65  9.579210e-06
# 12                  Iowa   3.190.369    22  6.895754e-06
# 13                Kansas   2.937.880     3  1.021144e-06
# 14              Kentucky   4.505.836    31  6.879966e-06
# 15             Louisiana   4.657.757     5  1.073478e-06
# 16                 Maine   1.362.359   361  2.649816e-04
# 17              Maryland   6.177.224   379  6.135442e-05
# 18         Massachusetts   7.029.917   107  1.522066e-05
# 19              Michigan  10.077.331    67  6.648586e-06
# 20             Minnesota   5.706.494   190  3.329540e-05
# 21           Mississippi   2.961.279     6  2.026152e-06
# 22              Missouri   6.154.913    42  6.823817e-06
# 23                Nevada   3.104.614    20  6.442025e-06
# 24         New Hampshire   1.377.529    44  3.194125e-05
# 25            New Jersey   9.288.994   552  5.942516e-05
# 26            New Mexico   2.117.522    82  3.872451e-05
# 27              New York  20.201.249   490  2.425593e-05
# 28        North Carolina  10.439.388   187  1.791293e-05
# 29                  Ohio  11.799.448   177  1.500070e-05
# 30              Oklahoma   3.959.353    31  7.829562e-06
# 31                Oregon   4.237.256    32  7.552057e-06
# 32          Pennsylvania  13.002.700   326  2.507172e-05
# 33          Rhode Island   1.097.379   130  1.184641e-04
# 34        South Carolina   5.118.425    21  4.102825e-06
# 35             Tennessee   6.910.840   112  1.620642e-05
# 36                 Texas  29.145.505     2  6.862122e-08
# 37                  Utah   3.271.616    66  2.017352e-05
# 38               Vermont     643.077    49  7.619616e-05
# 39              Virginia   8.631.393  1025  1.187526e-04
# 40            Washington   7.705.281   634  8.228123e-05
# 41         West Virginia   1.793.716    27  1.505255e-05
# 42             Wisconsin   5.893.718    83  1.408279e-05

# %% [markdown]
# # 10. For each dog, compute the number of days from the posted day to the day of last access.

# %%
dogs['posted'] = dogs['posted'].dt.tz_localize(None)
dogs['posted'] = dogs['posted'].dt.date

dogs['accessed'] = pd.to_datetime(dogs['accessed'] , format="%Y-%m-%d")
dogs['accessed'] = (dogs['accessed']).dt.date

# %%
dogs[['accessed','posted']]
# Out:
#          accessed      posted
# 0      2019-09-20  2019-09-20
# 1      2019-09-20  2019-09-20
# 2      2019-09-20  2019-09-20
# 3      2019-09-20  2019-09-20
# 4      2019-09-20  2019-09-20
# ...           ...         ...
# 58175  2019-09-20  2019-05-03
# 58176  2019-09-20  2019-04-13
# 58177  2019-09-20  2018-09-27
# 58178  2019-09-20  2018-09-12
# 58179  2019-09-20  2018-09-03
#
# [58180 rows x 2 columns]

# %%
dogs['days_diff'] = (dogs['accessed'] - dogs['posted']).dt.days  
dogs[['id' , 'days_diff']]
# Out:
#              id  days_diff
# 0      46042150          0
# 1      46042002          0
# 2      46040898          0
# 3      46039877          0
# 4      46039306          0
# ...         ...        ...
# 58175  44605893        140
# 58176  44457061        160
# 58177  42865848        358
# 58178  42734734        373
# 58179  42663515        382
#
# [58180 rows x 2 columns]

# %% [markdown]
# # 11. Partition the dogs according to the number of weeks from the posted day to the day of last access.

# %%
dogs['weeks_diff'] = abs(dogs['days_diff'])//7
dogs.sort_values(by=['weeks_diff'])[['id' , 'weeks_diff']].set_index(['weeks_diff'])
# Out:
#                   id
# weeks_diff
# 0           46042150
# 0           45968226
# 0           45968176
# 0           45968114
# 0           45968101
# ...              ...
# 729          5142790
# 746          4527948
# 811          2613506
# 812          2592031
# 852           604115
#
# [58180 rows x 1 columns]

# %% [markdown]
# # 12. Find for duplicates in the dogs dataset. Two records are duplicates if they have (1) same breeds and sex, and (2) they share at least 90% of the words in the description field. Extra points if you find and implement a more refined for determining if two rows are duplicates.

# %%
comp = dogs[dogs.duplicated(subset=['breed_primary' , 'sex'],keep=False)][['id','breed_primary', 'sex','description']]
comp['description'] = comp['description'].astype(str)
comp = comp[comp['description'] != 'nan']
comp.set_index(['breed_primary' , 'sex'], inplace=True)
comp
# Out:
#                                              id  \
# breed_primary                  sex
# American Staffordshire Terrier Male    46042150
# Pit Bull Terrier               Male    46042002
# Shepherd                       Male    46040898
# Dachshund                      Male    46039306
# Boxer                          Male    46039304
# ...                                         ...
# Australian Shepherd            Male    45168741
# Pit Bull Terrier               Male    44843897
#                                Male    44658860
# Border Collie                  Male    44605893
#                                Female  42865848
#
#                                                                              description
# breed_primary                  sex
# American Staffordshire Terrier Male    Harley is not sure how he wound up at shelter ...
# Pit Bull Terrier               Male    6 year old Biggie has lost his home and really...
# Shepherd                       Male    Approx 2 years old.\n Did I catch your eye? I ...
# Dachshund                      Male    Theo is a friendly dachshund mix who gets alon...
# Boxer                          Male    Oliver was born around mid-June and came to us...
# ...                                                                                  ...
# Australian Shepherd            Male    Charlie was adopted from us 5 years ago, but r...
# Pit Bull Terrier               Male    Samson is a dog that will need someone to show...
#                                Male    Buddy was an owner surrender by an older gentl...
# Border Collie                  Male    Due to the small size of our volunteer base, w...
#                                Female  Due to the small size of our volunteer base, w...
#
# [49437 rows x 2 columns]

# %%
comp.sort_index(inplace=True)
comp
# Out:
#                                 id  \
# breed_primary     sex
# Affenpinscher     Female  45889013
#                   Female  22427951
#                   Female  45970614
#                   Female  45871731
#                   Female  45916762
# ...                            ...
# Yorkshire Terrier Male    45958435
#                   Male    45922985
#                   Male    45466492
#                   Male    45985506
#                   Male    45945521
#
#                                                                 description
# breed_primary     sex
# Affenpinscher     Female  This cutie is very sweet. She is a little shy ...
#                   Female  To see even more click the following link:\n\n...
#                   Female  Elsie.jpgThank you for looking at our availabl...
#                   Female  55351.jpgThank you for looking at our availabl...
#                   Female  Norma Jean is an Affenpinscher mix girl that w...
# ...                                                                     ...
# Yorkshire Terrier Male    For a quicker response please submit a online ...
#                   Male    You can fill out an adoption application onlin...
#                   Male    My name is Juno from California and I am a won...
#                   Male    2 years, 4 pounds, cute, lovable, friendly, aw...
#                   Male    Energetic 8 yo male.\nHe is selective about ot...
#
# [49437 rows x 2 columns]

# %%
def pulizia(x):
    string1_words = set(x['description'].split())
    unwanted_characters = ".,!?)(][:;-_ /*"
    string1_words = {word.strip(unwanted_characters).lower() for word in string1_words}
    return(string1_words)

# %%
comp['description'] = comp['description'].str.replace("\n" , " ")
comp['description'] = comp['description'].apply(lambda x: fix_encoding(x))
comp['words'] = comp.apply(pulizia, axis=1)

# %%
from collections import Counter
def similarity(words1 , words2):
    a = Counter(words1)
    b = Counter(words2)
    intersect=[]
    space = max(len(words1) , len(words2))
    for i in set(words1).intersection(set(words2)):
        intersect.extend([i] * min(a[i] , b[i]))
        
    return (len(intersect) / space)

# %%
def test(x: pd.DataFrame):    
    found = list()
    for index1, row1 in x.iloc[1:].iterrows():
        for index2, row2 in x.iloc[::-1].iterrows():
            if row1['id'] == row2['id']:
                break
            elif similarity(row1['words'] , row2['words']) >= 0.9:
                found.append([row1['id'], row2['id']])

    return found

# %%
coppie = comp.groupby(axis=0 , level=[0,1]).apply(test)

# %%
coppie
# Out:
# breed_primary                      sex
# Affenpinscher                      Female                               [[45970614, 45871731]]
#                                    Male                                                     []
# Afghan Hound                       Male                                                     []
# Airedale Terrier                   Female                                                   []
#                                    Male                                                     []
#                                                                    ...
# Xoloitzcuintli / Mexican Hairless  Male                                                     []
# Yellow Labrador Retriever          Female    [[46023037, 46022945], [46023037, 46023018], [...
#                                    Male           [[44266927, 44267041], [46014773, 46014715]]
# Yorkshire Terrier                  Female    [[41166946, 41166968], [45251495, 42906237], [...
#                                    Male      [[45569684, 45569511], [43971538, 43971630], [...
# Length: 365, dtype: object

# %%
coppiedf=pd.DataFrame(coppie)
coppiedf['numero'] = coppiedf[0].apply(lambda x:len(x))
coppiedf['numero'].sum()
# Out:
# 7736
